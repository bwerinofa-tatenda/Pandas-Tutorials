# %% [markdown]
# ##  Summary Functions

# %%
reviews.describe() #gives a statistical summary of the data

# %%
#to see the mean(how well the average of the distribution does)
reviews.points.mean()

#the list of unique values:
reviews.taster_name.unique()

#to see a list of unique values and how often they occur in the dataset:
reviews.taster_name.value_counts()

# %% [markdown]
# ## Maps
# - its a function that takes one set of values and 'maps' them to another set of values.

# %% [markdown]
# There are two mapping methods that are comments:
# 1. **map()** - if, for example we wanted to remean the scores the wines recieved to 0:

# %%
review_points_mean = reviews.points.mean()
reviews.points.map(lambda p: p - review_points_mean)

# %% [markdown]
# the function you pass to **map()** should expect a single value from the Series, and return a transformed version of that value. **map()** returns a new Series where all the values have been transformed by your function
#
# **apply()** is the equivalent method if we want to transform a whole DataFrame by calling a custom method on each row

# %%
def remean_points(row):
    row.points = row.points - review_points_mean
    return row

reviews.apply(remean_points, axis='columns')

# %% [markdown]
# if we had called reviews.apply() with axis='index', then instead of passing a function to transform each _row_, we would need to give a function to transform each _column_
#
# - _note that_ **map()** _and_ **apply()** _return new transformed Series and DataFrames, respectively_

# %%
#pandas provides some common mapping operations as built-ins. e.g remeaning the points:
review_points_mean = review.points.mean()
review.points - review_points_mean

#pandas will also perform these operations between series of equal lessons
#e.g an easy way to combine country and region information in the dataset:
reviews.country + "..." + reviews.region_1
